# %%
import pygmt
fig = pygmt.Figure()

# %%
fig = pygmt.Figure()
fig.coast(shorelines="1/0.5p", region=[3.2, 7.22, 50.75, 53.7], projection='M6i')
fig.basemap(frame="a+ue")
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(shorelines="1/0.5p", region=[3.2, 7.22, 50.75, 53.7], projection="S5.387/90/4.5i")
fig.basemap(frame=["a+ue", "wsEN"])
fig.show()

# %%
fig = pygmt.Figure()
fig.basemap(region=[3.2, 7.22, 50.75, 53.7], projection='m0/1:4000000', frame=0)
fig.coast(shorelines="1/0.5p")
fig.basemap(region='646.36/449000/308975.28/845000+ue', projection='x1:4000000', frame=["ag", "WSEN"])
fig.show()

# %%
fig = pygmt.Figure()
fig.coast(shorelines='1/0.5p', region=[3.2, 7.22, 50.75, 53.7], projection='S5.387/90/4.5i', frame=0)
fig.basemap(region='646.36/449000/308975.28/845000+ue', projection='x1:4000000', frame=['ag', 'WSEN'])
fig.show()

# %%
fig = pygmt.Figure()
fig.basemap(region=[3.2, 7.22, 50.75, 53.7], projection='+proj=stere+lat_0=52.15616055555555+lon_0=5.38763888888889+k=0.9999079+x_0=155000+y_0=463000+ellps=bessel+units=m+no_defs',
            frame=['ag', 'WSEN'])
fig.coast(shorelines='1/0.5p')
fig.show()
